# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('./Diabetes dataset/Clean_diabetes_dataset.csv')
df.head(10)
# Out:
#    Unnamed: 0  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  \
# 0           0            6      148             72             35        0
# 1           1            1       85             66             29        0
# 2           2            8      183             64              0        0
# 3           3            1       89             66             23       94
# 4           5            5      116             74              0        0
# 5           6            3       78             50             32       88
# 6          10            4      110             92              0        0
# 7          11           10      168             74              0        0
# 8          14            5      166             72             19      175
# 9          16            0      118             84             47      230
#
#     BMI  DiabetesPedigreeFunction  Age  Outcome
# 0  33.6                     0.627   50        1
# ...

# %%
# checking co-relationn 
corr_matrix = df.corr()
corr_matrix
# Out:
#                           Unnamed: 0  Pregnancies   Glucose  BloodPressure  \
# Unnamed: 0                  1.000000    -0.036976  0.015439       0.028201
# Pregnancies                -0.036976     1.000000  0.142093       0.210666
# Glucose                     0.015439     0.142093  1.000000       0.238754
# BloodPressure               0.028201     0.210666  0.238754       1.000000
# SkinThickness               0.035387    -0.094425 -0.004609       0.037388
# Insulin                     0.033558    -0.114510  0.248225      -0.041513
# BMI                         0.038722     0.036958  0.192504       0.303301
# DiabetesPedigreeFunction   -0.011275     0.009289  0.066530       0.024290
# Age                         0.019538     0.567438  0.286682       0.354036
# Outcome                    -0.028682     0.227987  0.492740       0.183298
#
#                           SkinThickness   Insulin       BMI  \
# Unnamed: 0                     0.035387  0.033558  0.038722
# ...

# %%
corr_matrix['Outcome']*100
# Out:
# Unnamed: 0                   -2.868235
# Pregnancies                  22.798663
# Glucose                      49.274005
# BloodPressure                18.329784
# SkinThickness                 3.067563
# Insulin                       9.774559
# BMI                          26.937130
# DiabetesPedigreeFunction     17.907250
# Age                          26.334387
# Outcome                     100.000000
# Name: Outcome, dtype: float64

# %%
df.drop(columns = ['Unnamed: 0','SkinThickness','Insulin','DiabetesPedigreeFunction'], inplace=True)

# %%
df.head(10)
# Out:
#    Pregnancies  Glucose  BloodPressure   BMI  Age  Outcome
# 0            6      148             72  33.6   50        1
# 1            1       85             66  26.6   31        0
# 2            8      183             64  23.3   32        1
# 3            1       89             66  28.1   21        0
# 4            5      116             74  25.6   30        0
# 5            3       78             50  31.0   26        1
# 6            4      110             92  37.6   30        0
# 7           10      168             74  38.0   34        1
# 8            5      166             72  25.8   51        1
# 9            0      118             84  45.8   31        1

# %%
inputs = df.drop('Outcome',axis='columns')
target = df['Outcome']

# %%
from sklearn import tree
mdl = tree.DecisionTreeClassifier()
mdl.fit(inputs,target)
# Out:
# DecisionTreeClassifier()

# %%
mdl.score(inputs,target)
# Out:
# 1.0

# %%
y_pred = mdl.predict(inputs)
from sklearn.metrics import confusion_matrix, classification_report
cm = confusion_matrix(inputs, y_pred)
# print(classification_report(inputs, y_pred))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 3
#       1 y_pred = mdl.predict(inputs)
#       2 from sklearn.metrics import confusion_matrix, classification_report
# ----> 3 cm = confusion_matrix(inputs, y_pred)
#       4 # print(classification_report(inputs, y_pred))
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\_param_validation.py:211, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     205 try:
#     206     with config_context(
#     207         skip_parameter_validation=(
#     208             prefer_skip_nested_validation or global_skip_validation
#     209         )
#     210     ):
# --> 211         return func(*args, **kwargs)
#     212 except InvalidParameterError as e:
#     213     # When the function is just a wrapper around an estimator, we allow
# ...
