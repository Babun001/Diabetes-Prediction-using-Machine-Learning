# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
diabetes_dataframe = pd.read_csv('./Diabetes dataset/diabetes.csv')
diabetes_dataframe.head(6)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1
# 5                     0.201   30        0

# %%
diabetes_dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
# checking co-relationn 
corr_matrix = diabetes_dataframe.corr()
corr_matrix
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# ...

# %%
corr_matrix['Outcome']*100
# Out:
# Pregnancies                  22.189815
# Glucose                      46.658140
# BloodPressure                 6.506836
# SkinThickness                 7.475223
# Insulin                      13.054795
# BMI                          29.269466
# DiabetesPedigreeFunction     17.384407
# Age                          23.835598
# Outcome                     100.000000
# Name: Outcome, dtype: float64

# %%
plt.figure(figsize=(12,10))
sns.heatmap(diabetes_dataframe.corr(), annot=True, cmap='RdYlGn')
# Out:
# <Axes: >

# %%
plt.figure(figsize=(15,15))
plt.subplot(2, 3, 1)
sns.distplot(diabetes_dataframe['Pregnancies'])
plt.subplot(2, 3, 2)
sns.distplot(diabetes_dataframe['Glucose'])
plt.subplot(2, 3, 3)
sns.distplot(diabetes_dataframe['SkinThickness'])
plt.subplot(2, 3, 4)
sns.distplot(diabetes_dataframe['Insulin'])
plt.subplot(2, 3, 5)
sns.distplot(diabetes_dataframe['BMI'])
plt.subplot(2, 3, 6)
sns.distplot(diabetes_dataframe['DiabetesPedigreeFunction'])
# Out:
# C:\Users\babun\AppData\Local\Temp\ipykernel_16128\2857686039.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(diabetes_dataframe['Pregnancies'])
# C:\Users\babun\AppData\Local\Temp\ipykernel_16128\2857686039.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
def checkSkew (arr):
    for a in arr:
        print(diabetes_dataframe[a].skew())

# %%
arr = diabetes_dataframe.columns
checkSkew(arr)
# Out:
# 0.9016739791518588
# 0.17375350179188992
# -1.8436079833551302
# 0.10937249648187608
# 2.272250858431574
# -0.42898158845356543
# 1.919911066307204
# 1.1295967011444805
# 0.635016643444986

# %%
diabetes_dataframe['Pregnancies'].describe()
# Out:
# count    768.000000
# mean       3.845052
# std        3.369578
# min        0.000000
# 25%        1.000000
# 50%        3.000000
# 75%        6.000000
# max       17.000000
# Name: Pregnancies, dtype: float64

# %%
plt.figure(figsize=(15,15))
plt.subplot(2, 2, 1)
sns.boxplot(diabetes_dataframe['Pregnancies'])
per_75_1, per_25_1 = diabetes_dataframe['Pregnancies'].quantile(0.75), diabetes_dataframe['Pregnancies'].quantile(0.25)
iqr_1 = per_75_1 - per_25_1
upperLimit_1, lowerLimit_1 = (per_75_1 + 1.5*iqr_1), (per_25_1 - 1.5 * iqr_1)
clean_dataframe = pd.DataFrame(diabetes_dataframe[(diabetes_dataframe['Pregnancies']<upperLimit_1) & (diabetes_dataframe['Pregnancies']>lowerLimit_1)])
plt.subplot(2, 2, 2)
sns.boxplot(clean_dataframe['Pregnancies'])
clean_dataframe.describe()a
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   764.000000  764.000000     764.000000     764.000000  764.000000
# mean      3.786649  120.776178      69.098168      20.476440   79.683246
# std       3.278714   31.946234      19.401789      15.966814  115.436078
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   27.000000
# 75%       6.000000  140.000000      80.000000      32.000000  127.250000
# max      13.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  764.000000                764.000000  764.000000  764.000000
# mean    31.966099                  0.472260   33.187173    0.345550
# std      7.894034                  0.331619   11.764745    0.475859
# ...

# %%
plt.figure(figsize=(15,15))
plt.subplot(2, 2, 1)
sns.boxplot(diabetes_dataframe['Glucose'])
per_75_2, per_25_2 = diabetes_dataframe['Glucose'].quantile(0.75), diabetes_dataframe['Glucose'].quantile(0.25)
iqr_2 = per_75_2 - per_25_2
upperLimit_2, lowerLimit_2 = (per_75_2 + 1.5*iqr_2), (per_25_2 - 1.5 * iqr_2)
clean_dataframe = pd.DataFrame(diabetes_dataframe[(diabetes_dataframe['Glucose']<upperLimit_2) & (diabetes_dataframe['Glucose']>lowerLimit_2)])
plt.subplot(2, 2, 2)
sns.boxplot(clean_dataframe['Glucose'])
clean_dataframe.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   763.000000  763.000000     763.000000     763.000000  763.000000
# mean      3.851900  121.686763      69.115334      20.477064   80.292267
# std       3.374729   30.535641      19.399240      15.973171  115.457448
# min       0.000000   44.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   36.000000
# 75%       6.000000  141.000000      80.000000      32.000000  128.500000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  763.000000                763.000000  763.000000  763.000000
# mean    31.986763                  0.472477   33.271298    0.348624
# std      7.893221                  0.331963   11.772161    0.476847
# ...

# %%
plt.figure(figsize=(15,15))
plt.subplot(2, 2, 1)
sns.boxplot(diabetes_dataframe['BloodPressure'])
per_75, per_25 = diabetes_dataframe['BloodPressure'].quantile(0.75), diabetes_dataframe['BloodPressure'].quantile(0.25)
iqr = per_75 - per_25
upperLimit, lowerLimit = (per_75 + 1.5*iqr), (per_25 - 1.5 * iqr)
clean_dataframe = diabetes_dataframe[(diabetes_dataframe['BloodPressure']<upperLimit-10) & (diabetes_dataframe['BloodPressure']>lowerLimit+10)]
plt.subplot(2, 2, 2)
sns.boxplot(clean_dataframe['BloodPressure'])
clean_dataframe['BloodPressure'].describe()
# Out:
# count    705.000000
# mean      71.958865
# std       10.607660
# min       46.000000
# 25%       64.000000
# 50%       72.000000
# 75%       80.000000
# max       96.000000
# Name: BloodPressure, dtype: float64

# %%
plt.figure(figsize=(15,15))
plt.subplot(2, 2, 1)
sns.boxplot(diabetes_dataframe['SkinThickness'])
per_75, per_25 = diabetes_dataframe['SkinThickness'].quantile(0.75), diabetes_dataframe['SkinThickness'].quantile(0.25)
iqr = per_75 - per_25
upperLimit, lowerLimit = (per_75 + 1.5*iqr), (per_25 - 1.5 * iqr)
clean_dataframe = diabetes_dataframe[(diabetes_dataframe['SkinThickness']<upperLimit) & (diabetes_dataframe['SkinThickness']>lowerLimit)]
plt.subplot(2, 2, 2)
sns.boxplot(clean_dataframe['SkinThickness'])
clean_dataframe.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   767.000000  767.000000     767.000000     767.000000  767.000000
# mean      3.847458  120.795306      69.104302      20.434159   79.903520
# std       3.371117   31.874936      19.368410      15.708524  115.283105
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   32.000000
# 75%       6.000000  140.000000      80.000000      32.000000  127.500000
# max      17.000000  199.000000     122.000000      63.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  767.000000                767.000000  767.000000  767.000000
# mean    31.989048                  0.471742   33.203390    0.348110
# std      7.888698                  0.331524   11.721879    0.476682
# ...

# %%
plt.figure(figsize=(15,15))
plt.subplot(2, 2, 1)
sns.boxplot(diabetes_dataframe['Insulin'])
per_75, per_25 = diabetes_dataframe['Insulin'].quantile(0.75), diabetes_dataframe['Insulin'].quantile(0.25)
iqr = per_75 - per_25
upperLimit, lowerLimit = (per_75 + 1.5*iqr), (per_25 - 1.5 * iqr)
clean_dataframe = diabetes_dataframe[(diabetes_dataframe['Insulin']<upperLimit) & (diabetes_dataframe['Insulin']>lowerLimit)]
plt.subplot(2, 2, 2)
sns.boxplot(clean_dataframe['Insulin'])
# Out:
# <Axes: >

# %%
plt.figure(figsize=(15,15))
plt.subplot(2, 2, 1)
sns.boxplot(diabetes_dataframe['BMI'])
per_75, per_25 = diabetes_dataframe['BMI'].quantile(0.75), diabetes_dataframe['BMI'].quantile(0.25)
iqr = per_75 - per_25
upperLimit, lowerLimit = (per_75 + 1.5*iqr), (per_25 - 1.5 * iqr)
clean_dataframe = diabetes_dataframe[(diabetes_dataframe['BMI']<upperLimit) & (diabetes_dataframe['BMI']>lowerLimit)]
plt.subplot(2, 2, 2)
sns.boxplot(clean_dataframe['BMI'])
# Out:
# <Axes: >

# %%
plt.figure(figsize=(15,15))
plt.subplot(2, 2, 1)
sns.boxplot(diabetes_dataframe['DiabetesPedigreeFunction'])
per_75, per_25 = diabetes_dataframe['DiabetesPedigreeFunction'].quantile(0.75), diabetes_dataframe['DiabetesPedigreeFunction'].quantile(0.25)
iqr = per_75 - per_25
upperLimit, lowerLimit = (per_75 + 1.5*iqr), (per_25 - 1.5 * iqr)
clean_dataframe = diabetes_dataframe[(diabetes_dataframe['DiabetesPedigreeFunction']<upperLimit) & (diabetes_dataframe['DiabetesPedigreeFunction']>lowerLimit)]
plt.subplot(2, 2, 2)
sns.boxplot(clean_dataframe['DiabetesPedigreeFunction'])
# Out:
# <Axes: >

# %%
plt.figure(figsize=(15,15))
plt.subplot(2, 2, 1)
sns.boxplot(diabetes_dataframe['Age'])
per_75, per_25 = diabetes_dataframe['Age'].quantile(0.75), diabetes_dataframe['Age'].quantile(0.25)
iqr = per_75 - per_25
upperLimit, lowerLimit = (per_75 + 1.5*iqr), (per_25 - 1.5 * iqr)
clean_dataframe = diabetes_dataframe[(diabetes_dataframe['Age']<upperLimit) & (diabetes_dataframe['Age']>lowerLimit)]
plt.subplot(2, 2, 2)
sns.boxplot(clean_dataframe['Age'])
# Out:
# <Axes: >

# %%
plt.figure(figsize=(15,15))
plt.subplot(2, 3, 1)
sns.distplot(clean_dataframe['Pregnancies'])
plt.subplot(2, 3, 2)
sns.distplot(clean_dataframe['Glucose'])
plt.subplot(2, 3, 3)
sns.distplot(clean_dataframe['SkinThickness'])
plt.subplot(2, 3, 4)
sns.distplot(clean_dataframe['Insulin'])
plt.subplot(2, 3, 5)
sns.distplot(clean_dataframe['BMI'])
plt.subplot(2, 3, 6)
sns.distplot(clean_dataframe['DiabetesPedigreeFunction'])
# Out:
# C:\Users\babun\AppData\Local\Temp\ipykernel_16128\3882061473.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(clean_dataframe['Pregnancies'])
# C:\Users\babun\AppData\Local\Temp\ipykernel_16128\3882061473.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
clean_dataframe.to_csv('clean_dataframe.csv')
